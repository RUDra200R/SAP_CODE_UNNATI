# %% [markdown]
# # EDUNET FOUNDATION-Class Exercise Notebook

# %% [markdown]
# ## LAB 1 - Demonstrating Linear Regression on Emission Data

# %% [markdown]
# ### Load python libraries and sklear linear model library

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from sklearn import linear_model

# %% [markdown]
# ### Read the .csv and load into DataFrame

# %%
df=pd.read_csv("FuelConsumption.csv")
df
# Out:
#      Year   MAKE           MODEL             VEHICLE CLASS  ENGINE SIZE  \
# 0    2000  ACURA           1.6EL                   COMPACT          1.6
# 1    2000  ACURA           1.6EL                   COMPACT          1.6
# 2    2000  ACURA           3.2TL                  MID-SIZE          3.2
# 3    2000  ACURA           3.5RL                  MID-SIZE          3.5
# 4    2000  ACURA         INTEGRA                SUBCOMPACT          1.8
# ..    ...    ...             ...                       ...          ...
# 634  2000  VOLVO   V70 AWD TURBO  STATION WAGON - MID-SIZE          2.4
# 635  2000  VOLVO   V70 GLT TURBO  STATION WAGON - MID-SIZE          2.4
# 636  2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 637  2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 638  2000  VOLVO  V70R AWD TURBO  STATION WAGON - MID-SIZE          2.4
#
#      CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION  COEMISSIONS
# 0            4           A4    X              10.5           216
# 1            4           M5    X               9.8           205
# 2            6          AS5    Z              13.7           265
# 3            6           A4    Z              15.0           301
# 4            4           A4    X              11.4           230
# ..         ...          ...  ...               ...           ...
# 634          5           A4    Z              14.4           288
# 635          5           A4    Z              13.6           274
# 636          5           A4    Z              13.9           274
# 637          5           M5    Z              13.0           260
# 638          5           A5    Z              14.7           299
#
# [639 rows x 10 columns]

# %% [markdown]
# ### Lets Explore the Data

# %%
print(df.info())
print("\n")
print(df.describe(include="all"))      # to get the non-numeric value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 639 entries, 0 to 638
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              639 non-null    int64
#  1   MAKE              639 non-null    object
#  2   MODEL             639 non-null    object
#  3   VEHICLE CLASS     639 non-null    object
#  4   ENGINE SIZE       639 non-null    float64
#  5   CYLINDERS         639 non-null    int64
#  6   TRANSMISSION      639 non-null    object
#  7   FUEL              639 non-null    object
#  8   FUEL CONSUMPTION  639 non-null    float64
#  9   COEMISSIONS       639 non-null    int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 50.1+ KB
# None
#
#
#           Year       MAKE  MODEL VEHICLE CLASS  ENGINE SIZE   CYLINDERS  \
# count    639.0        639    639           639   639.000000  639.000000
# unique     NaN         36    328            14          NaN         NaN
# top        NaN  CHEVROLET  JETTA       COMPACT          NaN         NaN
# freq       NaN         63      6           105          NaN         NaN
# mean    2000.0        NaN    NaN           NaN     3.265728    5.805947
# std        0.0        NaN    NaN           NaN     1.231012    1.625588
# min     2000.0        NaN    NaN           NaN     1.000000    3.000000
# 25%     2000.0        NaN    NaN           NaN     2.200000    4.000000
# 50%     2000.0        NaN    NaN           NaN     3.000000    6.000000
# 75%     2000.0        NaN    NaN           NaN     4.300000    6.000000
# max     2000.0        NaN    NaN           NaN     8.000000   12.000000
#
#        TRANSMISSION FUEL  FUEL CONSUMPTION  COEMISSIONS
# count           639  639        639.000000    639.000000
# unique            8    5               NaN           NaN
# top              A4    X               NaN           NaN
# freq            324  454               NaN           NaN
# mean            NaN  NaN         14.713615    296.809077
# std             NaN  NaN          3.307044     65.504178
# min             NaN  NaN          4.900000    104.000000
# 25%             NaN  NaN         12.500000    253.000000
# 50%             NaN  NaN         14.400000    288.000000
# 75%             NaN  NaN         16.600000    343.000000
# max             NaN  NaN         30.200000    582.000000

# %%
df.isna().sum()     #To find the null value in the data
# Out:
# Year                0
# MAKE                0
# MODEL               0
# VEHICLE CLASS       0
# ENGINE SIZE         0
# CYLINDERS           0
# TRANSMISSION        0
# FUEL                0
# FUEL CONSUMPTION    0
# COEMISSIONS         0
# dtype: int64

# %% [markdown]
# ### Check the data column names

# %%
df.columns
# Out:
# Index(['Year', 'MAKE', 'MODEL', 'VEHICLE CLASS', 'ENGINE SIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUEL', 'FUEL CONSUMPTION', 'COEMISSIONS '],
#       dtype='object')

# %% [markdown]
# ### Lets Pick the Significant data columns

# %%
df.columns
cdf=df[['ENGINE SIZE','CYLINDERS','FUEL CONSUMPTION','COEMISSIONS ']]  ### Selected appended and DataFrame create
cdf.head()
# Out:
#    ENGINE SIZE  CYLINDERS  FUEL CONSUMPTION  COEMISSIONS
# 0          1.6          4              10.5           216
# 1          1.6          4               9.8           205
# 2          3.2          6              13.7           265
# 3          3.5          6              15.0           301
# 4          1.8          4              11.4           230

# %% [markdown]
# ### Lets get some visualization from data

# %%
viz = cdf[['ENGINE SIZE','CYLINDERS','FUEL CONSUMPTION','COEMISSIONS ']]
viz.hist()
plt.show()

# %% [markdown]
# ### Get scatter plot between dependent and independent variables

# %%
for i in cdf[['ENGINE SIZE','CYLINDERS','FUEL CONSUMPTION','COEMISSIONS ']]:
    plt.scatter(cdf[i],cdf['COEMISSIONS '],color='blue')
    plt.xlabel(i)
    plt.ylabel("Emission")
    plt.show()

# %% [markdown]
# ### Create Train and Test Data

# %%
mask=np.random.rand(len(df)) < 0.80                   ### Uniform Random Number
train=cdf[mask]
test=cdf[~mask]                                       ## ~mask has the value other than mask

# %% [markdown]
# ### Lets Check Training Data pattern

# %%
for i in train[['ENGINE SIZE','CYLINDERS','FUEL CONSUMPTION','COEMISSIONS ']]:
    plt.scatter(train[i],train['COEMISSIONS '],color='blue')
    plt.xlabel(i)
    plt.ylabel("Emission")
    plt.show()

# %% [markdown]
# ### Apply Linear Regression on Training data

# %%
coefficient=[]
intercept=[]
regress_model={}
for i in train[['ENGINE SIZE','CYLINDERS','FUEL CONSUMPTION','COEMISSIONS ']]:
    regr=linear_model.LinearRegression()
    train_x = np.asanyarray(train[[i]])
    train_y=  np.asanyarray(train[['COEMISSIONS ']])
    regr.fit(train_x, train_y)
    regress_model[i]=regr
    print("Relation between {} & {}".format(i,"'COEMISSIONS'"))
    print ('Coefficients: ', regr.coef_)
    print ('Intercept: ',regr.intercept_)
    coefficient.append(regr.coef_)              ## coefficient is considered as slope
    intercept.append(regr.intercept_)           ## intercept is considered as the line equation( y= mx +c)
    
    print('\n')
# Out:
# Relation between ENGINE SIZE & 'COEMISSIONS'
# Coefficients:  [[47.14312393]]
# Intercept:  [143.66266689]
#
#
# Relation between CYLINDERS & 'COEMISSIONS'
# Coefficients:  [[33.62741318]]
# Intercept:  [102.0828764]
#
#
# Relation between FUEL CONSUMPTION & 'COEMISSIONS'
# Coefficients:  [[19.48632913]]
# Intercept:  [10.25998283]
#
#
# Relation between COEMISSIONS  & 'COEMISSIONS'
# Coefficients:  [[1.]]
# Intercept:  [0.]

# %% [markdown]
# ### Use regression parameter to model linear equation

# %%
j=0
for i in train[['ENGINE SIZE','CYLINDERS','FUEL CONSUMPTION','COEMISSIONS ']]:
    plt.scatter(train[i], train['COEMISSIONS '],  color='blue')
    x=train[i].values
    print(x.shape)
    y=coefficient[j][0]*x + intercept[j]
    print(y.shape)
    l=len(y)
    y=np.reshape(y,(l,))
    plt.plot(x, y, '-r')
    plt.xlabel(i)
    plt.ylabel("Emission")
    plt.show()
    j=j+1
# Out:
# (501,)
# (501,)
# (501,)
# (501,)
# (501,)
# (501,)
# (501,)
# (501,)

# %% [markdown]
# ### Evaluate model performance on test data

# %%
from sklearn.metrics import r2_score

for i in train[['ENGINE SIZE','CYLINDERS','FUEL CONSUMPTION','COEMISSIONS ']]:
    test_x = np.asanyarray(test[[i]])
    test_y = np.asanyarray(test[['COEMISSIONS ']])
    test_y_ = regress_model[i].predict(test_x)
    print("Fitting Error between {} & {}".format(i,"'CO2EMISSIONS'"))
    print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
    print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
    print("R2-score: %.2f" % r2_score(test_y_ , test_y) )
    print('\n')
# Out:
# Fitting Error between ENGINE SIZE & 'CO2EMISSIONS'
# Mean absolute error: 25.99
# Residual sum of squares (MSE): 1185.65
# R2-score: 0.71
#
#
# Fitting Error between CYLINDERS & 'CO2EMISSIONS'
# Mean absolute error: 32.20
# Residual sum of squares (MSE): 1749.43
# R2-score: 0.50
#
#
# Fitting Error between FUEL CONSUMPTION & 'CO2EMISSIONS'
# Mean absolute error: 7.55
# Residual sum of squares (MSE): 106.29
# R2-score: 0.97
#
#
# Fitting Error between COEMISSIONS  & 'CO2EMISSIONS'
# Mean absolute error: 0.00
# Residual sum of squares (MSE): 0.00
# R2-score: 1.00
